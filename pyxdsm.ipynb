# %%
from pyxdsm.XDSM import XDSM

# Initialize the PyXDSM diagram
x = XDSM()

# Define the input and output nodes
x.add_input('mass_fuel', label='Mass of fuel')
x.add_output('aero.*', label='Aerodynamic forces and moments')
x.add_output('alt', label='Altitude')

# Add the subsystems to the diagram
x.add_system('mass_comp', 'MassComp', ['mass_fuel'], ['W_total'])
x.add_system('atmos', 'USatm1976Comp', ['alt'], ['pres', 'sos', 'rho'])
x.add_system('tas_comp', 'TrueAirspeedComp', ['TAS'], ['TAS'])
x.add_system('gam_comp', 'SteadyFlightPathAngleComp', ['TAS'], ['gam'])
x.add_system('q_comp', 'DynamicPressureComp', ['TAS', 'rho'], ['q'])
x.add_system('flight_equilibrium', 'SteadyFlightEquilibriumGroup', ['aero.*', 'alt'], ['W_total', 'CT', 'gam', 'q'])
x.add_system('propulsion', 'PropulsionGroup', ['alt', 'pres', 'CT'], ['thrust', 'q'])
x.add_system('range_rate_comp', 'RangeRateComp', ['TAS', 'gam'], ['dXdt'])

# Connect the nodes with arrows
x.connect('mass_fuel', 'mass_comp.mass_fuel', label='mass_fuel')
x.connect('mass_comp.W_total', 'flight_equilibrium.W_total', label='W_total')
x.connect('alt', 'atmos.alt', label='alt')
x.connect('atmos.pres', 'propulsion.pres', label='pres')
x.connect('atmos.sos', 'tas_comp.sos', label='sos')
x.connect('atmos.rho', 'q_comp.rho', label='rho')
x.connect('tas_comp.TAS', 'gam_comp.TAS', label='TAS')
x.connect('tas_comp.TAS', 'q_comp.TAS', label='TAS')
x.connect('tas_comp.TAS', 'range_rate_comp.TAS', label='TAS')
x.connect('gam_comp.gam', 'flight_equilibrium.gam', label='gam')
x.connect('gam_comp.gam', 'range_rate_comp.gam', label='gam')
x.connect('q_comp.q', 'aero.q', label='q')
x.connect('q_comp.q', 'flight_equilibrium.q', label='q')
x.connect('q_comp.q', 'propulsion.q', label='q')
x.connect('flight_equilibrium.CT', 'propulsion.CT', label='CT')
x.connect('flight_equilibrium.W_total', 'propulsion.W_total', label='W_total')
x.connect('alt', 'propulsion.alt', label='alt')
x.connect('propulsion.thrust', 'range_rate_comp.thrust', label='thrust')
x.connect('range_rate_comp.dXdt', 'mass_fuel.dXdt', label='dXdt')
x.connect('gam_comp.gam', 'traj.phase0.controls:climb_rate', label='gam')
x.connect('aero.*', 'traj.phase0.states:alt', label='aero.*')
x.connect('aero.*', 'flight_equilibrium.CL', label='aero.*')
x.connect('aero.*', 'flight_equilibrium.CD', label='aero.*')
x.connect('aero.*', 'flight_equilibrium.mach', label='aero.*')
x.connect('aero.*', 'aero.alt', label='aero.*')
x.connect('propulsion.dXdt', 'traj.phase0.states:mass_fuel.dXdt', label='mass_fuel_rate')

# Draw the PyXDSM diagram
x.write('pyxdsm_images/aircraft_ode_pyxdsm', cleanup=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 50
#      47 x.connect('propulsion.dXdt', 'traj.phase0.states:mass_fuel.dXdt', label='mass_fuel_rate')
#      49 # Draw the PyXDSM diagram
# ---> 50 x.write('pyxdsm_images/aircraft_ode_pyxdsm', cleanup=False)
#
# File ~/opt/anaconda3/envs/dymos_rangemax/lib/python3.11/site-packages/pyxdsm/XDSM.py:658, in XDSM.write(self, file_name, build, cleanup, quiet, outdir)
#     631 def write(self, file_name, build=True, cleanup=True, quiet=False, outdir="."):
#     632     """
#     633     Write output files for the XDSM diagram.  This produces the following:
#     634
#    (...)
#     656         path is given, it is interpreted relative to the current working directory.
#     657     """
# --> 658     nodes = self._build_node_grid()
#     659     edges = self._build_edges()
# ...

# %%
from pyxdsm.XDSM import XDSM

# Initialize the PyXDSM diagram
x = XDSM()

# Define the input and output nodes
x.add_input('mass_fuel', label='Mass of fuel')
x.add_output('aero.*', label='Aerodynamic forces and moments')
x.add_output('alt', label='Altitude')
x.add_output('dXdt', label='Range rate')

# Add the subsystems to the diagram
x.add_system('mass_comp', 'MassComp', ['mass_fuel'], ['W_total'])
x.add_system('atmos', 'USatm1976Comp', ['alt'], ['pres', 'sos', 'rho'])
x.add_system('tas_comp', 'TrueAirspeedComp', ['TAS'], ['TAS'])
x.add_system('gam_comp', 'SteadyFlightPathAngleComp', ['TAS'], ['gam'])
x.add_system('q_comp', 'DynamicPressureComp', ['TAS', 'rho'], ['q'])
x.add_system('flight_equilibrium', 'SteadyFlightEquilibriumGroup', ['aero.*', 'alt'], ['W_total', 'CT', 'gam', 'q'])
x.add_system('propulsion', 'PropulsionGroup', ['alt', 'pres', 'CT'], ['thrust', 'dXdt'])
x.add_system('range_rate_comp', 'RangeRateComp', ['TAS', 'gam'], ['dXdt'])

# Draw the PyXDSM diagram
x.write('pyxdsm_images/aircraft_ode_pyxdsm', cleanup=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 23
#      20 x.add_system('range_rate_comp', 'RangeRateComp', ['TAS', 'gam'], ['dXdt'])
#      22 # Draw the PyXDSM diagram
# ---> 23 x.write('pyxdsm_images/aircraft_ode_pyxdsm', cleanup=False)
#
# File ~/opt/anaconda3/envs/dymos_rangemax/lib/python3.11/site-packages/pyxdsm/XDSM.py:658, in XDSM.write(self, file_name, build, cleanup, quiet, outdir)
#     631 def write(self, file_name, build=True, cleanup=True, quiet=False, outdir="."):
#     632     """
#     633     Write output files for the XDSM diagram.  This produces the following:
#     634
#    (...)
#     656         path is given, it is interpreted relative to the current working directory.
#     657     """
# --> 658     nodes = self._build_node_grid()
#     659     edges = self._build_edges()
#     660     process = self._build_process_chain()
#
# ...

# %%
from pyxdsm.XDSM import XDSM

# Initialize the PyXDSM diagram
x = XDSM()

# Define the input and output nodes
x.add_input('mass_fuel', label='Mass of fuel')
x.add_output('aero.*', label='Aerodynamic forces and moments')
x.add_output('alt', label='Altitude')
x.add_output('dXdt', label='Range rate')

# Add the subsystems to the diagram
x.add_system('mass_comp', 'MassComp', ['mass_fuel'], ['W_total'])
x.add_system('atmos', 'USatm1976Comp', ['alt'], ['pres', 'sos', 'rho'])
x.add_system('tas_comp', 'TrueAirspeedComp', ['TAS'], ['TAS'])
x.add_system('gam_comp', 'SteadyFlightPathAngleComp', ['TAS'], ['gam'])
x.add_system('q_comp', 'DynamicPressureComp', ['TAS', 'rho'], ['q'])
x.add_system('flight_equilibrium', 'SteadyFlightEquilibriumGroup', ['aero.*', 'alt'], ['W_total', 'CT', 'gam', 'q'])
x.add_system('propulsion', 'PropulsionGroup', ['alt', 'pres', 'CT'], ['thrust', 'dXdt'])
x.add_system('range_rate_comp', 'RangeRateComp', ['TAS', 'gam'], ['dXdt'])

# Draw the PyXDSM diagram
x.write('pyxdsm_images/aircraft_ode_pyxdsm', cleanup=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 23
#      20 x.add_system('range_rate_comp', 'RangeRateComp', ['TAS', 'gam'], ['dXdt'])
#      22 # Draw the PyXDSM diagram
# ---> 23 x.write('pyxdsm_images/aircraft_ode_pyxdsm', cleanup=False)
#
# File ~/opt/anaconda3/envs/dymos_rangemax/lib/python3.11/site-packages/pyxdsm/XDSM.py:658, in XDSM.write(self, file_name, build, cleanup, quiet, outdir)
#     631 def write(self, file_name, build=True, cleanup=True, quiet=False, outdir="."):
#     632     """
#     633     Write output files for the XDSM diagram.  This produces the following:
#     634
#    (...)
#     656         path is given, it is interpreted relative to the current working directory.
#     657     """
# --> 658     nodes = self._build_node_grid()
#     659     edges = self._build_edges()
#     660     process = self._build_process_chain()
#
# ...

# %%
from pyxdsm.XDSM import XDSM

# Initialize the PyXDSM diagram
x = XDSM()

# Define the input and output nodes
x.add_input('mass_fuel', label='Mass of fuel')
x.add_output('L', label='Lift force')
x.add_output('D', label='Drag force')
x.add_output('M', label='Rolling moment')
x.add_output('N', label='Yawing moment')
x.add_output('alt', label='Altitude')
x.add_output('dXdt', label='Range rate')

# Add the subsystems to the diagram
x.add_system('mass_comp', 'MassComp', ['mass_fuel'], ['W_total'])
x.add_system('atmos', 'USatm1976Comp', ['alt'], ['pres', 'sos', 'rho'])
x.add_system('tas_comp', 'TrueAirspeedComp', ['TAS'], ['TAS'])
x.add_system('gam_comp', 'SteadyFlightPathAngleComp', ['TAS'], ['gam'])
x.add_system('q_comp', 'DynamicPressureComp', ['TAS', 'rho'], ['q'])
x.add_system('flight_equilibrium', 'SteadyFlightEquilibriumGroup', ['L', 'D', 'M', 'N', 'alt'], ['W_total', 'CT', 'gam', 'q'])
x.add_system('propulsion', 'PropulsionGroup', ['alt', 'pres', 'CT'], ['thrust', 'dXdt'])
x.add_system('range_rate_comp', 'RangeRateComp', ['TAS', 'gam'], ['dXdt'])



# Connect the nodes with arrows
x.connect('mass_fuel', 'mass_comp.mass_fuel', label='mass_fuel')
x.connect('mass_comp.W_total', 'flight_equilibrium.W_total', label='W_total')
x.connect('alt', 'atmos.alt', label='alt')
x.connect('atmos.pres', 'propulsion.pres', label='pres')
x.connect('atmos.sos', 'tas_comp.sos', label='sos')
x.connect('atmos.rho', 'q_comp.rho', label='rho')
x.connect('tas_comp.TAS', 'gam_comp.TAS', label='TAS')
x.connect('tas_comp.TAS', 'q_comp.TAS', label='TAS')
x.connect('tas_comp.TAS', 'range_rate_comp.TAS', label='TAS')
x.connect('gam_comp.gam', 'flight_equilibrium.gam', label='gam')
x.connect('gam_comp.gam', 'range_rate_comp.gam', label='gam')
x.connect('q_comp.q', 'flight_equilibrium.q', label='q')
x.connect('flight_equilibrium.L', 'L', label='L')
x.connect('flight_equilibrium.D', 'D', label='D')
x.connect('flight_equilibrium.M', 'M', label='M')
x.connect('flight_equilibrium.N', 'N', label='N')
x.connect('flight_equilibrium.CT', 'propulsion.CT', label='CT')
x.connect('flight_equilibrium.W_total', 'propulsion.W_total', label='W_total')
x.connect('alt', 'propulsion.alt', label='alt')
x.connect('propulsion.thrust', 'range_rate_comp.thrust', label='thrust')
x.connect('propulsion.dXdt', 'traj.phase0.states:mass_fuel.dXdt', label='mass_fuel')
x.connect('gam_comp.gam', 'traj.phase0.controls:climb_rate', label='gam')
x.connect('aero.L', 'L', label='L')
x.connect('aero.D', 'D', label='D')
x.connect('aero.M', 'M', label='M')
x.connect('aero.N', 'N', label='N')
x.connect('aero.CL', 'flight_equilibrium.CL', label='CL')
x.connect('aero.CD', 'flight_equilibrium.CD', label='CD')
x.connect('aero.mach', 'flight_equilibrium.mach', label='mach')

# Draw the PyXDSM diagram
x.write('pyxdsm_images/aircraft_ode_pyxdsm', cleanup=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 59
#      56 x.connect('aero.mach', 'flight_equilibrium.mach', label='mach')
#      58 # Draw the PyXDSM diagram
# ---> 59 x.write('pyxdsm_images/aircraft_ode_pyxdsm', cleanup=False)
#
# File ~/opt/anaconda3/envs/dymos_rangemax/lib/python3.11/site-packages/pyxdsm/XDSM.py:658, in XDSM.write(self, file_name, build, cleanup, quiet, outdir)
#     631 def write(self, file_name, build=True, cleanup=True, quiet=False, outdir="."):
#     632     """
#     633     Write output files for the XDSM diagram.  This produces the following:
#     634
#    (...)
#     656         path is given, it is interpreted relative to the current working directory.
#     657     """
# --> 658     nodes = self._build_node_grid()
#     659     edges = self._build_edges()
#     660     process = self._build_process_chain()
#
# ...

# %%
from pyxdsm.XDSM import XDSM

x = XDSM()

# Define subsystems
x.add_system('mass', 'Function', 'mass_comp')
x.add_system('atmos', 'Function', 'atmos')
x.add_system('tas', 'Function', 'tas_comp')
x.add_system('gam', 'Function', 'gam_comp')
x.add_system('q', 'Function', 'q_comp')
x.add_system('flight_eq', 'Function', 'flight_equilibrium')
x.add_system('propulsion', 'Function', 'propulsion')
x.add_system('range_rate', 'Function', 'range_rate_comp')

# Define connections
x.connect('mass', 'flight_eq')
x.connect('atmos', 'propulsion')
x.connect('atmos', 'tas')
x.connect('atmos', 'q')
x.connect('tas', 'gam')
x.connect('tas', 'q')
x.connect('tas', 'range_rate')
x.connect('gam', 'flight_eq')
x.connect('gam', 'range_rate')
x.connect('q', 'flight_eq')
x.connect('q', 'propulsion')
x.connect('flight_eq', 'propulsion')
x.connect('propulsion', 'range_rate')

# Generate the diagram
x.write('aircraft_ode', file_format='pdf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 16
#      13 x.add_system('range_rate', 'Function', 'range_rate_comp')
#      15 # Define connections
# ---> 16 x.connect('mass', 'flight_eq')
#      17 x.connect('atmos', 'propulsion')
#      18 x.connect('atmos', 'tas')
#
# TypeError: XDSM.connect() missing 1 required positional argument: 'label'

# %%
from pyxdsm.XDSM import XDSM

x = XDSM()

# Define subsystems
x.add_system('mass', 'Function', 'mass_comp')
x.add_system('atmos', 'Function', 'atmos')
x.add_system('tas', 'Function', 'tas_comp')
x.add_system('gam', 'Function', 'gam_comp')
x.add_system('q', 'Function', 'q_comp')
x.add_system('flight_eq', 'Function', 'flight_equilibrium')
x.add_system('propulsion', 'Function', 'propulsion')
x.add_system('range_rate', 'Function', 'range_rate_comp')

# Define connections
x.connect('mass', 'flight_eq', 'W_total')
x.connect('atmos', 'propulsion', 'pres, sos, rho')
x.connect('atmos', 'tas', 'sos')
x.connect('atmos', 'q', 'rho')
x.connect('tas', 'gam', 'TAS')
x.connect('tas', 'q', 'TAS')
x.connect('tas', 'range_rate', 'TAS')
x.connect('gam', 'flight_eq', 'gam')
x.connect('gam', 'range_rate', 'gam')
x.connect('q', 'flight_eq', 'q')
x.connect('q', 'propulsion', 'q')
x.connect('flight_eq', 'propulsion', 'CT')
x.connect('propulsion', 'range_rate', 'CT')

# Generate the diagram
x.write('aircraft_ode', file_format='pdf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 31
#      28 x.connect('propulsion', 'range_rate', 'CT')
#      30 # Generate the diagram
# ---> 31 x.write('aircraft_ode', file_format='pdf')
#
# TypeError: XDSM.write() got an unexpected keyword argument 'file_format'

# %%
from pyxdsm.XDSM import XDSM

x = XDSM()

# Define subsystems
x.add_system('mass', 'Function', 'mass_comp')
x.add_system('atmos', 'Function', 'atmos')
x.add_system('tas', 'Function', 'tas_comp')
x.add_system('gam', 'Function', 'gam_comp')
x.add_system('q', 'Function', 'q_comp')
x.add_system('flight_eq', 'Function', 'flight_equilibrium')
x.add_system('propulsion', 'Function', 'propulsion')
x.add_system('range_rate', 'Function', 'range_rate_comp')

# Define connections
x.connect('mass', 'flight_eq', 'W_total')
x.connect('atmos', 'propulsion', 'pres, sos, rho')
x.connect('atmos', 'tas', 'sos')
x.connect('atmos', 'q', 'rho')
x.connect('tas', 'gam', 'TAS')
x.connect('tas', 'q', 'TAS')
x.connect('tas', 'range_rate', 'TAS')
x.connect('gam', 'flight_eq', 'gam')
x.connect('gam', 'range_rate', 'gam')
x.connect('q', 'flight_eq', 'q')
x.connect('q', 'propulsion', 'q')
x.connect('flight_eq', 'propulsion', 'CT')
x.connect('propulsion', 'range_rate', 'CT')

# Generate the diagram
x.write('aircraft_ode.pdf')
# Out:
# This is pdfTeX, Version 3.141592653-2.6-1.40.25 (TeX Live 2023) (preloaded format=pdflatex)
#  restricted \write18 enabled.
# entering extended mode
# (./aircraft_ode.pdf.tex
# LaTeX2e <2022-11-01> patch level 1
# L3 programming layer <2023-02-22>
# (/usr/local/texlive/2023/texmf-dist/tex/latex/base/article.cls
# Document Class: article 2022/07/02 v1.4n Standard LaTeX document class
# (/usr/local/texlive/2023/texmf-dist/tex/latex/base/size10.clo))
# (/usr/local/texlive/2023/texmf-dist/tex/latex/geometry/geometry.sty
# (/usr/local/texlive/2023/texmf-dist/tex/latex/graphics/keyval.sty)
# (/usr/local/texlive/2023/texmf-dist/tex/generic/iftex/ifvtex.sty
# (/usr/local/texlive/2023/texmf-dist/tex/generic/iftex/iftex.sty)))
# (/usr/local/texlive/2023/texmf-dist/tex/latex/amsfonts/amsfonts.sty)
# (/usr/local/texlive/2023/texmf-dist/tex/latex/amsmath/amsmath.sty
# For additional information on amsmath, use the `?' option.
# (/usr/local/texlive/2023/texmf-dist/tex/latex/amsmath/amstext.sty
# ...
